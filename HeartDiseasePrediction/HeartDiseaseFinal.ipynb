# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('/content/heart (1).csv')

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
from matplotlib import pyplot as plt
df['Age'].plot(kind='hist', bins=20, title='Age')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df.tail()
# Out:
#        Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 12049   29   M           NAP        105          165          0     Normal
# 12050   37   F           ATA        151          243          0         ST
# 12051   47   M           ATA        101          341          0         ST
# 12052   67   M            TA        123          245          1         ST
# 12053   46   F           ATA        179          235          0        LVH
#
#        MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 12049    193              Y      2.3     Down             0
# 12050    137              Y      2.4       Up             0
# 12051     96              Y      0.0     Flat             1
# 12052    143              N      4.0     Down             0
# 12053    164              N      4.7       Up             0

# %%
df.describe()
# Out:
#                 Age     RestingBP   Cholesterol     FastingBS         MaxHR  \
# count  12054.000000  12054.000000  12054.000000  12054.000000  12054.000000
# mean      50.010785    139.106106    246.050025      0.481500    144.265970
# std       14.468861     23.063779     64.579495      0.499678     31.511347
# min       25.000000      0.000000      0.000000      0.000000     60.000000
# 25%       38.000000    120.000000    199.000000      0.000000    118.000000
# 50%       50.000000    138.000000    247.000000      0.000000    144.000000
# 75%       62.000000    159.000000    298.000000      1.000000    171.000000
# max       77.000000    200.000000    603.000000      1.000000    202.000000
#
#             Oldpeak  HeartDisease
# count  12054.000000   12054.00000
# mean       2.287747       0.49917
# std        1.505075       0.50002
# min       -2.600000       0.00000
# 25%        1.000000       0.00000
# 50%        2.100000       0.00000
# 75%        3.600000       1.00000
# max        6.200000       1.00000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12054 entries, 0 to 12053
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             12054 non-null  int64
#  1   Sex             12054 non-null  object
#  2   ChestPainType   12054 non-null  object
#  3   RestingBP       12054 non-null  int64
#  4   Cholesterol     12054 non-null  int64
#  5   FastingBS       12054 non-null  int64
#  6   RestingECG      12054 non-null  object
#  7   MaxHR           12054 non-null  int64
#  8   ExerciseAngina  12054 non-null  object
#  9   Oldpeak         12054 non-null  float64
#  10  ST_Slope        12054 non-null  object
#  11  HeartDisease    12054 non-null  int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 1.1+ MB

# %%
df.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
df.shape
# Out:
# (12054, 12)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df.columns
# Out:
# Index(['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS',
#        'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope',
#        'HeartDisease'],
#       dtype='object')

# %%
df['Sex'] = le.fit_transform(df['Sex'])
df['ChestPainType'] = le.fit_transform(df['ChestPainType'])
df['RestingECG'] = le.fit_transform(df['RestingECG'])
df['ExerciseAngina'] = le.fit_transform(df['ExerciseAngina'])
df['ST_Slope'] = le.fit_transform(df['ST_Slope'])

# %%
df.head()
# Out:
#    Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0   40    1              1        140          289          0           1
# 1   49    0              2        160          180          0           1
# 2   37    1              1        130          283          0           2
# 3   48    0              0        138          214          0           1
# 4   54    1              2        150          195          0           1
#
#    MaxHR  ExerciseAngina  Oldpeak  ST_Slope  HeartDisease
# 0    172               0      0.0         2             0
# 1    156               0      1.0         1             1
# 2     98               0      0.0         2             0
# 3    108               1      1.5         1             1
# 4    122               0      0.0         2             0

# %%
corr = df.corr()

# %%
from sklearn.preprocessing import StandardScaler , MinMaxScaler

# %%
std_scaler = StandardScaler()
mm_scaler = StandardScaler()

# %%
df['Age'] = std_scaler.fit_transform(df[['Age']])
df['RestingBP'] = std_scaler.fit_transform(df[['RestingBP']])
df['MaxHR'] = std_scaler.fit_transform(df[['MaxHR']])
df['Cholesterol'] = std_scaler.fit_transform(df[['Cholesterol']])
df['Oldpeak'] = std_scaler.fit_transform(df[['Oldpeak']])

# %%
plt.figure(figsize = (20,10))
sns.boxplot(df)
# Out:
# <Axes: >

# %%
plt.figure(figsize = (20,5))
sns.heatmap(df.corr(),cmap = "PiYG",annot = True);

# %%
curr = df.corrwith(df['HeartDisease']).sort_values(ascending = False).to_frame()

# %%
sns.heatmap(curr ,cmap = 'PiYG' , annot = True)
# Out:
# <Axes: >

# %%
X = df.drop(df[['HeartDisease','RestingBP' , 'RestingECG']], axis = 1)
y = df['HeartDisease']

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
X_train , X_test , y_train , y_test = train_test_split(X, y , test_size = 0.33 , stratify = y)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report , confusion_matrix  ,ConfusionMatrixDisplay

# %%
def model(classifier):
    classifier.fit(X_train,y_train)
    global prediction
    prediction = classifier.predict(X_test)
    print("Accuracy : ",'{0:.2%}'.format(accuracy_score(y_test,prediction)))

# %%
def conf_matrix(y_test , prediction , model_name):
  ax = plt.figure(figsize = (100,100))
  confu_matrix = confusion_matrix(y_test , prediction)
  disp = ConfusionMatrixDisplay(confu_matrix).plot()
  disp.ax_.set_title(model_name.upper())

# %%
def classificationn_report( y_test , prediction , model_name):
  print(f"                     {model_name.upper()}")

  print(classification_report(y_test , prediction))

# %%
LogisticRegression = LogisticRegression()

# %%
model(LogisticRegression)
# Out:
# Accuracy :  53.57%

# %%
classificationn_report( y_test ,  prediction , 'logistic regression')
# Out:
#                      LOGISTIC REGRESSION
#               precision    recall  f1-score   support
#
#            0       0.54      0.54      0.54      1992
#            1       0.54      0.53      0.53      1986
#
#     accuracy                           0.54      3978
#    macro avg       0.54      0.54      0.54      3978
# weighted avg       0.54      0.54      0.54      3978

# %%
conf_matrix( y_test , prediction ,  'logistic regression')

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
DTC = DecisionTreeClassifier(max_depth =3)
model(DTC)
# Out:
# Accuracy :  53.29%

# %%
from sklearn import tree
fig = plt.figure(figsize=(15,10))
_ = tree.plot_tree(DTC, feature_names=X.columns, class_names= 'HeartDisease', filled=True)

# %%
classificationn_report( y_test ,prediction , 'decision tree')
# Out:
#                      DECISION TREE
#               precision    recall  f1-score   support
#
#            0       0.52      0.76      0.62      1992
#            1       0.56      0.31      0.40      1986
#
#     accuracy                           0.53      3978
#    macro avg       0.54      0.53      0.51      3978
# weighted avg       0.54      0.53      0.51      3978

# %%
conf_matrix( y_test , prediction , 'decision tree')

# %%
from xgboost import XGBClassifier , plot_tree

# %%
xgbc = XGBClassifier(max_depth=2)

# %%
model(xgbc)
# Out:
# Accuracy :  53.29%

# %%
def model(classifier):
    classifier.fit(X_train,y_train)
    global prediction
    prediction = classifier.predict(X_test)
    print("Accuracy : ",'{0:.2%}'.format(accuracy_score(y_test,prediction)))

# %%
plot_tree(xgbc); plt.show()
plot_tree(xgbc, num_trees=4); plt.show()

# %%
classificationn_report( y_test , prediction , 'xgboost')
# Out:
#                      XGBOOST
#               precision    recall  f1-score   support
#
#            0       0.53      0.52      0.53      1992
#            1       0.53      0.54      0.54      1986
#
#     accuracy                           0.53      3978
#    macro avg       0.53      0.53      0.53      3978
# weighted avg       0.53      0.53      0.53      3978

# %%
conf_matrix( y_test , prediction , 'xgboost')

# %%
XGBClassifier().get_params()
# Out:
# {'objective': 'binary:logistic',
#  'base_score': None,
#  'booster': None,
#  'callbacks': None,
#  'colsample_bylevel': None,
#  'colsample_bynode': None,
#  'colsample_bytree': None,
#  'device': None,
#  'early_stopping_rounds': None,
#  'enable_categorical': False,
#  'eval_metric': None,
#  'feature_types': None,
#  'gamma': None,
#  'grow_policy': None,
#  'importance_type': None,
#  'interaction_constraints': None,
#  'learning_rate': None,
#  'max_bin': None,
#  'max_cat_threshold': None,
#  'max_cat_to_onehot': None,
#  'max_delta_step': None,
#  'max_depth': None,
#  'max_leaves': None,
#  'min_child_weight': None,
#  'missing': nan,
#  'monotone_constraints': None,
#  'multi_strategy': None,
#  'n_estimators': None,
#  'n_jobs': None,
#  'num_parallel_tree': None,
#  'random_state': None,
#  'reg_alpha': None,
#  'reg_lambda': None,
#  'sampling_method': None,
#  'scale_pos_weight': None,
#  'subsample': None,
#  'tree_method': None,
#  'validate_parameters': None,
#  'verbosity': None}

# %%
params = {
    'n_estimators': [50 , 100, 300, 500 , 1000],
    'max_depth': [3, 5, 7 , 9],
    'learning_rate': [0.01, 0.1, 0.3 , 0.5],
    'gamma': [0, 0.1, 0.5, 1 , 1.5],
    'subsample': [0.5, 0.8, 1],
    'colsample_bytree': [0.5, 0.8, 1],
}

# %%
xgbccc = XGBClassifier()

# %%
from sklearn.model_selection import StratifiedKFold  , RandomizedSearchCV , cross_val_score

# %%
cv = StratifiedKFold(n_splits = 10 , shuffle = True )

# %%
rs = RandomizedSearchCV(xgbccc , param_distributions= params , cv = cv , n_iter = 10 , n_jobs = -1)

# %%
rs.fit(X, y)
# Out:
# RandomizedSearchCV(cv=StratifiedKFold(n_splits=10, random_state=None, shuffle=True),
#                    estimator=XGBClassifier(base_score=None, booster=None,
#                                            callbacks=None,
#                                            colsample_bylevel=None,
#                                            colsample_bynode=None,
#                                            colsample_bytree=None, device=None,
#                                            early_stopping_rounds=None,
#                                            enable_categorical=False,
#                                            eval_metric=None, feature_types=None,
#                                            gamma=None, grow_policy=None,
#                                            impor...
#                                            min_child_weight=None, missing=nan,
#                                            monotone_constraints=None,
#                                            multi_strategy=None,
#                                            n_estimators=None, n_jobs=None,
#                                            num_parallel_tree=None,
#                                            random_state=None, ...),
#                    n_jobs=-1,
#                    param_distributions={'colsample_bytree': [0.5, 0.8, 1],
#                                         'gamma': [0, 0.1, 0.5, 1, 1.5],
#                                         'learning_rate': [0.01, 0.1, 0.3, 0.5],
#                                         'max_depth': [3, 5, 7, 9],
#                                         'n_estimators': [50, 100, 300, 500,
#                                                          1000],
#                                         'subsample': [0.5, 0.8, 1]})

# %%
print(rs.best_params_)
# Out:
# {'subsample': 1, 'n_estimators': 1000, 'max_depth': 5, 'learning_rate': 0.1, 'gamma': 0.5, 'colsample_bytree': 0.8}

# %%
best_model = rs.best_estimator_
best_model
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=0.5, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=5, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=1000, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
score = cross_val_score(best_model , X , y , cv = cv , scoring = 'accuracy')

# %%
score.mean()
# Out:
# 0.5284544084556471

# %%
models1 = pd.DataFrame({
    'Model': ['Logistic Regression', 'Decision Tree' , 'XGBoost' , 'XGBoost with tuned hyperparamaters and cross validation'],
    'Score': [83.17 , 82.18 , 85.15 , score.mean() * 100 ]})
models1.sort_values(by='Score', ascending=False).style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_51ed9_row0_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_51ed9_row1_col1 {
#   background-color: #840711;
#   color: #f1f1f1;
# }
# #T_51ed9_row2_col1 {
#   background-color: #940b13;
#   color: #f1f1f1;
# }
# #T_51ed9_row3_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_51ed9" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_51ed9_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_51ed9_level0_col1" class="col_heading level0 col1" >Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_51ed9_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_51ed9_row0_col0" class="data row0 col0" >XGBoost</td>
#       <td id="T_51ed9_row0_col1" class="data row0 col1" >85.150000</td>
#     </tr>
#     <tr>
#       <th id="T_51ed9_level0_row1" class="row_heading level0 row1" >0</th>
#       <td id="T_51ed9_row1_col0" class="data row1 col0" >Logistic Regression</td>
#       <td id="T_51ed9_row1_col1" class="data row1 col1" >83.170000</td>
#     </tr>
#     <tr>
#       <th id="T_51ed9_level0_row2" class="row_heading level0 row2" >1</th>
#       <td id="T_51ed9_row2_col0" class="data row2 col0" >Decision Tree</td>
#       <td id="T_51ed9_row2_col1" class="data row2 col1" >82.180000</td>
#     </tr>
#     <tr>
#       <th id="T_51ed9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_51ed9_row3_col0" class="data row3 col0" >XGBoost with tuned hyperparamaters and cross validation</td>
#       <td id="T_51ed9_row3_col1" class="data row3 col1" >52.845441</td>
#     </tr>
#   </tbody>
# </table>
